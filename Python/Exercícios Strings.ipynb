# %% [markdown]
# Exercício 1

# %%
frase = "Hello World!"
print(frase)
# Out:
# Hello World!

# %% [markdown]
# Exercício 2

# %%
nome = "Gabriel Antônio Dias Lanfranca Maida"
print(len(nome))
# Out:
# 36

# %% [markdown]
# Exercício 3

# %%
email = "bomdia@gmail.com"
print("@" in email)
# Out:
# True

# %% [markdown]
# Exercício 4

# %%
frase_1 = "Hello World! "
frase_2 = "Olá Mundo!"
print(frase_1 + frase_2)
# Out:
# Hello World! Olá Mundo!

# %% [markdown]
# Exercício 5

# %%
texto = "Bom dia pessoal, eu gosto de python. Python é legal, eu gosto mesmo de python."
print(texto.count("python"))
# Out:
# 2

# %% [markdown]
# Exercício 6

# %%
frase = "Bom dia galera."
print(frase.upper())
# Out:
# BOM DIA GALERA.

# %% [markdown]
# Exercício 7

# %%
nome = "Gabriel"
print(nome[::-1])
# Out:
# leirbaG

# %% [markdown]
# Exercício 8

# %%
frase = "bom dia gente"
print(frase.split())
# Out:
# ['bom', 'dia', 'gente']

# %% [markdown]
# Exercício 9

# %%
frase = "frase de exemplo"
print(frase.count('a'))
# Out:
# 1

# %% [markdown]
# Exercício 10

# %%
frase = "Salve pessoal"
print(frase.replace("a", "e"))
# Out:
# Selve pessoel

# %% [markdown]
# Exercício 11

# %%
nome = "Gabriel Antônio Dias Lanfranca Maida"
#print(nome.find("Antônio"))
print(nome.index("Antônio"))
# Out:
# 8

# %% [markdown]
# Exercício 12

# %%
frase = "bom dia professor Fabiano"
print(frase[:3])
# Out:
# bom

# %% [markdown]
# OU

# %%
frase = "bom dia professor Fabiano"
#print(frase.split(' ')[0])
print(frase.split()[0])
# Out:
# bom

# %% [markdown]
# Exercício 13

# %%
frase = "bom dia professor"
print(frase[-1])
# Out:
# r

# %% [markdown]
# Exercício 14

# %%
frase = "boa tarde professor"
print(frase[4:9])
# Out:
# tarde

# %% [markdown]
# OU

# %%
frase = "boa tarde professor"
print(frase.split()[1])
# Out:
# tarde

# %% [markdown]
# Exercício 15

# %%
frase = "boa noite professor"
print(frase[::-1])
# Out:
# rosseforp etion aob
